# %% [markdown]
# Objetivo: Gerar uma base consolidada com quem jogou contra quem , placar final, quantidade de cartões jogo, lista de jogadores que marcaram gols em cada time
# Desafio : Quem foi o craque do campeonato? A partir de que momento do compeonato ele se tornou lider ?

# %%
import pandas as pd

# %%
cartoes=pd.read_csv("C:/Users/Usuario/Documents/Projetos/cumbuca_soccer/data/campeonato-brasileiro-cartoes.csv")
estatistica=pd.read_csv("C:/Users/Usuario/Documents/Projetos/cumbuca_soccer/data/campeonato-brasileiro-estatisticas-full.csv")
dvfull=pd.read_csv("C:/Users/Usuario/Documents/Projetos/cumbuca_soccer/data/campeonato-brasileiro-full.csv")
gols=pd.read_csv("C:/Users/Usuario/Documents/Projetos/cumbuca_soccer/data/campeonato-brasileiro-gols.csv")

# %% [markdown]
# Printando "Hello World"

# %%
cartoes
# Out:
#        partida_id  rodata          clube    cartao  \
# 0            4607       1    Figueirense   Amarelo
# 1            4607       1    Figueirense   Amarelo
# 2            4608       1  Internacional   Amarelo
# 3            4608       1        Vitoria   Amarelo
# 4            4608       1        Vitoria   Amarelo
# ...           ...     ...            ...       ...
# 18852        8405      38          Vasco   Amarelo
# 18853        8405      38          Vasco   Amarelo
# 18854        8405      38          Vasco   Amarelo
# 18855        8405      38     Bragantino   Amarelo
# 18856        8405      38     Bragantino  Vermelho
#
#                            atleta  num_camisa     posicao minuto
# 0          Paulo Roberto da Silva        28.0         NaN     66
# 1                   Thiago Heleno         4.0    Zagueiro     44
# 2             Andrés D'Alessandro        10.0  Meio-campo     72
# 3      Marcelo Machado dos Santos        29.0         NaN     86
# ...

# %%
estatistica
# Out:
#        partida_id  rodata         clube  chutes  chutes_no_alvo posse_de_bola  \
# 0               1       1       Guarani       0               0           NaN
# 1               1       1         Vasco       0               0           NaN
# 2               2       1        Gremio       0               0           NaN
# 3               2       1  Athletico-PR       0               0           NaN
# 4               3       1      Coritiba       0               0           NaN
# ...           ...     ...           ...     ...             ...           ...
# 16805        8403      38        Santos      15               6           55%
# 16806        8404      38     Sao Paulo       9               3           42%
# 16807        8404      38      Flamengo      10               2           58%
# 16808        8405      38         Vasco      13               6           45%
# 16809        8405      38    Bragantino       9               2           55%
#
# ...

# %%
pd.merge
# Out:
# <function pandas.core.reshape.merge.merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'MergeHow' = 'inner', on: 'IndexLabel | AnyArrayLike | None' = None, left_on: 'IndexLabel | AnyArrayLike | None' = None, right_on: 'IndexLabel | AnyArrayLike | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool | None' = None, indicator: 'str | bool' = False, validate: 'str | None' = None) -> 'DataFrame'>

# %%
estatistica.merge(cartoes,on=["partida_id", "rodata", "clube"], how="left")
# Out:
#        partida_id  rodata         clube  chutes  chutes_no_alvo posse_de_bola  \
# 0               1       1       Guarani       0               0           NaN
# 1               1       1         Vasco       0               0           NaN
# 2               2       1        Gremio       0               0           NaN
# 3               2       1  Athletico-PR       0               0           NaN
# 4               3       1      Coritiba       0               0           NaN
# ...           ...     ...           ...     ...             ...           ...
# 28662        8405      38         Vasco      13               6           45%
# 28663        8405      38         Vasco      13               6           45%
# 28664        8405      38         Vasco      13               6           45%
# 28665        8405      38    Bragantino       9               2           55%
# 28666        8405      38    Bragantino       9               2           55%
#
# ...

# %%
estatistica.merge(cartoes,on=["partida_id", "rodata", "clube"], how="left")
# Out:
#        partida_id  rodata         clube  chutes  chutes_no_alvo posse_de_bola  \
# 0               1       1       Guarani       0               0           NaN
# 1               1       1         Vasco       0               0           NaN
# 2               2       1        Gremio       0               0           NaN
# 3               2       1  Athletico-PR       0               0           NaN
# 4               3       1      Coritiba       0               0           NaN
# ...           ...     ...           ...     ...             ...           ...
# 28662        8405      38         Vasco      13               6           45%
# 28663        8405      38         Vasco      13               6           45%
# 28664        8405      38         Vasco      13               6           45%
# 28665        8405      38    Bragantino       9               2           55%
# 28666        8405      38    Bragantino       9               2           55%
#
# ...

# %%
estatistica.merge(cartoes,on=["partida_id", "rodata", "clube"], how="inner")
# Out:
#        partida_id  rodata          clube  chutes  chutes_no_alvo  \
# 0            4607       1    Figueirense       0               0
# 1            4607       1    Figueirense       0               0
# 2            4608       1  Internacional       0               0
# 3            4608       1  Internacional       0               0
# 4            4608       1        Vitoria       0               0
# ...           ...     ...            ...     ...             ...
# 18852        8405      38          Vasco      13               6
# 18853        8405      38          Vasco      13               6
# 18854        8405      38          Vasco      13               6
# 18855        8405      38     Bragantino       9               2
# 18856        8405      38     Bragantino       9               2
#
#       posse_de_bola  passes precisao_passes  faltas  cartao_amarelo  \
# 0               NaN       0             NaN       0               0
# ...

# %%
estatistica.merge(cartoes,on=["partida_id", "rodata", "clube"], how="outer")
# Out:
#        partida_id  rodata         clube  chutes  chutes_no_alvo posse_de_bola  \
# 0               1       1       Guarani       0               0           NaN
# 1               1       1         Vasco       0               0           NaN
# 2               2       1  Athletico-PR       0               0           NaN
# 3               2       1        Gremio       0               0           NaN
# 4               3       1      Coritiba       0               0           NaN
# ...           ...     ...           ...     ...             ...           ...
# 28662        8405      38    Bragantino       9               2           55%
# 28663        8405      38    Bragantino       9               2           55%
# 28664        8405      38         Vasco      13               6           45%
# 28665        8405      38         Vasco      13               6           45%
# 28666        8405      38         Vasco      13               6           45%
#
# ...

# %%
estatistica.merge(cartoes,on=["partida_id", "rodata", "clube"], how="outer")
# Out:
#        partida_id  rodata         clube  chutes  chutes_no_alvo posse_de_bola  \
# 0               1       1       Guarani       0               0           NaN
# 1               1       1         Vasco       0               0           NaN
# 2               2       1  Athletico-PR       0               0           NaN
# 3               2       1        Gremio       0               0           NaN
# 4               3       1      Coritiba       0               0           NaN
# ...           ...     ...           ...     ...             ...           ...
# 28662        8405      38    Bragantino       9               2           55%
# 28663        8405      38    Bragantino       9               2           55%
# 28664        8405      38         Vasco      13               6           45%
# 28665        8405      38         Vasco      13               6           45%
# 28666        8405      38         Vasco      13               6           45%
#
# ...

# %%
dvfull
# Out:
#         ID  rodata        data   hora       mandante     visitante  \
# 0        1       1  29/03/2003  16:00        Guarani         Vasco
# 1        2       1  29/03/2003  16:00   Athletico-PR        Gremio
# 2        3       1  30/03/2003  16:00       Flamengo      Coritiba
# 3        4       1  30/03/2003  16:00          Goias      Paysandu
# 4        5       1  30/03/2003  16:00  Internacional   Ponte Preta
# ...    ...     ...         ...    ...            ...           ...
# 8400  8401      38  06/12/2023  21:32          Bahia   Atletico-MG
# 8401  8402      38  06/12/2023  21:32         Cuiaba  Athletico-PR
# 8402  8403      38  06/12/2023  21:32         Santos     Fortaleza
# 8403  8404      38  06/12/2023  21:32      Sao Paulo      Flamengo
# 8404  8405      38  06/12/2023  21:32          Vasco    Bragantino
#
#      formacao_mandante formacao_visitante        tecnico_mandante  \
# 0                  NaN                NaN                     NaN
# ...

# %%
gols
# Out:
#       partida_id  rodata          clube                             atleta  \
# 0           4607       1     Fluminense            Nirley da Silva Fonseca
# 1           4607       1     Fluminense                               Fred
# 2           4607       1     Fluminense                       Rafael Sóbis
# 3           4608       1  Internacional                   Charles Aránguiz
# 4           4612       1       Cruzeiro             Nílton Ferreira Júnior
# ...          ...     ...            ...                                ...
# 8927        8403      38         Santos  Messias Rodrigues da Silva Júnior
# 8928        8404      38      Sao Paulo             Luciano da Rocha Neves
# 8929        8405      38          Vasco      Sergio Antonio De Luiz Junior
# 8930        8405      38     Bragantino                          Léo Ortiz
# 8931        8405      38          Vasco                           Paulinho
#
#      minuto tipo_de_gol
# 0        59  Gol Contra
# ...

# %%
estatistica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16810 entries, 0 to 16809
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   partida_id       16810 non-null  int64
#  1   rodata           16810 non-null  int64
#  2   clube            16810 non-null  object
#  3   chutes           16810 non-null  int64
#  4   chutes_no_alvo   16810 non-null  int64
#  5   posse_de_bola    6820 non-null   object
#  6   passes           16810 non-null  int64
#  7   precisao_passes  4512 non-null   object
#  8   faltas           16810 non-null  int64
#  9   cartao_amarelo   16810 non-null  int64
#  10  cartao_vermelho  16810 non-null  int64
#  11  impedimentos     16810 non-null  int64
#  12  escanteios       16810 non-null  int64
# dtypes: int64(10), object(3)
# memory usage: 1.7+ MB

# %%
estatistica.describe()
# Out:
#          partida_id        rodata        chutes  chutes_no_alvo        passes  \
# count  16810.000000  16810.000000  16810.000000    16810.000000  16810.000000
# mean    4203.000000     20.133254      5.233432        1.359310    171.247234
# std     2426.386661     11.444303      7.094100        2.387573    216.806317
# min        1.000000      1.000000      0.000000        0.000000      0.000000
# 25%     2102.000000     10.000000      0.000000        0.000000      0.000000
# 50%     4203.000000     20.000000      0.000000        0.000000      0.000000
# 75%     6304.000000     30.000000     11.000000        2.000000    387.000000
# max     8405.000000     46.000000     37.000000       18.000000    848.000000
#
#              faltas  cartao_amarelo  cartao_vermelho  impedimentos  \
# count  16810.000000    16810.000000     16810.000000  16810.000000
# mean       6.069185        0.940393         0.051933      0.664485
# ...

# %%
dvfull.head()
# Out:
#    ID  rodata        data   hora       mandante    visitante  \
# 0   1       1  29/03/2003  16:00        Guarani        Vasco
# 1   2       1  29/03/2003  16:00   Athletico-PR       Gremio
# 2   3       1  30/03/2003  16:00       Flamengo     Coritiba
# 3   4       1  30/03/2003  16:00          Goias     Paysandu
# 4   5       1  30/03/2003  16:00  Internacional  Ponte Preta
#
#   formacao_mandante formacao_visitante tecnico_mandante tecnico_visitante  \
# 0               NaN                NaN              NaN               NaN
# 1               NaN                NaN              NaN               NaN
# 2               NaN                NaN              NaN               NaN
# 3               NaN                NaN              NaN               NaN
# 4               NaN                NaN              NaN               NaN
#
#        vencedor              arena  mandante_Placar  visitante_Placar  \
# 0       Guarani     Brinco de Ouro                4                 2
# ...

# %%
gols.tail()
# Out:
#       partida_id  rodata       clube                             atleta  \
# 8927        8403      38      Santos  Messias Rodrigues da Silva Júnior
# 8928        8404      38   Sao Paulo             Luciano da Rocha Neves
# 8929        8405      38       Vasco      Sergio Antonio De Luiz Junior
# 8930        8405      38  Bragantino                          Léo Ortiz
# 8931        8405      38       Vasco                           Paulinho
#
#      minuto tipo_de_gol
# 8927     58         NaN
# 8928     26         NaN
# 8929     82         NaN
# 8930     63         NaN
# 8931     29         NaN

# %%
print('hello world')
# Out:
# hello world
